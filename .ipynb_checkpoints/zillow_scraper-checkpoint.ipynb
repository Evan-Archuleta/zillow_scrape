# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext

#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

#add headers in case you use chromedriver (captchas are no fun); namely used for chromedriver
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
#create url variables for each zillow page
with requests.Session() as s:
    city = 'denver/' #*****change this city to what you want!!!!*****
    
    url = 'https://www.zillow.com/homes/for_sale/'+city
    url2 = 'https://www.zillow.com/homes/for_sale/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_sale/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_sale/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_sale/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_sale/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_sale/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_sale/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_sale/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_sale/'+city+'/10_p/'

    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

page_links = [soup, soup1, soup2, soup3, soup4, soup5, soup6, soup7, soup8, soup9]

#create the first two dataframes
df_master = pd.DataFrame()
df = pd.DataFrame()
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()

dataframe_list = [df,df1,df2,df3, df4,df5,df6,df7,df8,df9,df10]

# %%
for df, soup in zip(dataframe_list, page_links):
    #all for loops are pulling the specified variable using beautiful soup and inserting into said variable
    for i in soup:
        address = soup.find_all (class_= 'list-card-addr')
        price = list(soup.find_all (class_='list-card-price'))
        beds = list(soup.find_all("ul", class_="list-card-details"))
        details = soup.find_all ('div', {'class': 'list-card-details'})
        home_type = soup.find_all ('div', {'class': 'list-card-footer'})
        last_updated = soup.find_all ('div', {'class': 'list-card-top'})
        brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
        link = soup.find_all (class_= 'list-card-link')


        #create dataframe columns out of variables
        df['prices'] = price
        df['address'] = address
        df['beds'] = beds


    #create empty url list
    urls = []

    #loop through url, pull the href and strip out the address tag
    for link in soup.find_all("article"):
        href = link.find('a',class_="list-card-link")
        if href == None:
            addresses = None
        else:
            addresses = href.find('address',class_="list-card-addr").get_text()
        urls.append(addresses)
        urls = [x for x in urls if x is not None]


    #import urls into a links column
    df['link'] = urls
    df['link'] = df['link'].astype('str')


    #remove html tags
    df['link'] = df['link'].replace(',', '', regex=True)
    df['link'] = df['link'].replace(' ', '-', regex=True)
    df['link'] = 'https://www.zillow.com/homedetails/' + df['link'].astype(str)

    #convert columns to str
    df['prices'] = df['prices'].astype('str')
    df['address'] = df['address'].astype('str')
    df['beds'] = df['beds'].astype('str')

    #remove html tags
    df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
    df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
    df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
    df['address'] = df['address'].replace('</address>', ' ', regex=True)
    df['prices'] = df['prices'].str.replace(r'\D', '')

    #remove html tags from beds column
    df['beds'] = df['beds'].replace('<ul class="list-card-details"><li>', ' ', regex=True)
    df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li>', ' ', regex=True)
    df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->bds</abbr></li><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->ba</abbr></li><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->bd</abbr></li><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<abbr class="list-card-label"> ', ' ', regex=True)
    df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li></ul>', ' ', regex=True)
    df['beds'] = df['beds'].replace('Studio</li><liclass=""', '0', regex=True)
    df['beds'] = df['beds'].replace('Studio</li><li>', '0', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Townhouse for sale</li></ul>', 'Townhouse ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
    df['beds'] = df['beds'].replace(' <!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Condo for sale</li></ul>', 'Condo ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Coming soon</li></ul>', 'Coming_soon ', regex=True)
    df['beds'] = df['beds'].replace(' <!-- -->sqft</abbr></li><li class="list-card-statusText">- New construction</li></ul>', ' New_construction ', regex=True)
    
    #split beds column into beds, bath and sq_feet
    df[['beds','baths','sq_feet', 'type']] = df.beds.str.split(expand=True)

    #remove commas from sq_feet and convert to float
    df.replace(',','', regex=True, inplace=True)

    #drop nulls
    df = df[(df['prices'] != '') & (df['prices']!= ' ')]

    #convert column to float
    df['prices'] = df['prices'].astype('float')
    # d['sq_feet'] = df['sq_feet'].astype('float')

    #remove spaces from link column
    df['link'] = df.link.str.replace(' ','')

    #rearrange the columns
    df = df[['prices', 'address', 'link', 'beds', 'baths', 'sq_feet', 'type']]

    try_link = []
    for link in soup.find_all('a'):
        a = link.get('href')
        try_link.append(a)


    df_2 = pd.DataFrame(try_link, columns = ['links'])
    df_2.dropna(inplace=True)
    df_2.drop_duplicates(inplace=True)
    try_link = df_2[df_2['links'].str.startswith('https://www.zillow.com/homedetails')]
    try_link.reset_index(inplace=True)


    df = df.merge(try_link, left_index=True, right_index=True)
    df = df.drop(['link','index'], axis =1)
    df_master = df_master.append(df, ignore_index = True)
# Out:
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_12676\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)

# %%
df_master.drop_duplicates(inplace=True)
df_master.sort_values(by='prices', ascending=False, inplace=True)
df['sq_feet'] = df['sq_feet'].astype(float)
df_master['sqft_price'] = df.prices / df.sq_feet
df_master.to_csv('output.csv', index=False)

# %%
df_master
# Out:
#        prices                                            address            beds       baths sq_feet              type                                              links  sqft_price
# 12  6295000.0                101 S Birch Street Denver CO 80246                5           4    5599             House  https://www.zillow.com/homedetails/101-S-Birch...         NaN
# 87  4700000.0         1735 19th Street  Unit 7b Denver CO 80202                3           5    5884             Condo  https://www.zillow.com/homedetails/1735-19th-S...         NaN
# 77  3400000.0                45 S Eudora Street Denver CO 80246                5           6    7236             House  https://www.zillow.com/homedetails/45-S-Eudora...         NaN
# 54  3000000.0                   2485 Oak Street Denver CO 80212                5           5    5875             House  https://www.zillow.com/homedetails/2485-Oak-St...         NaN
# 88  2775000.0              3115 Umatilla Street Denver CO 80211                5           5    4616             House  https://www.zillow.com/homedetails/3115-Umatil...         NaN
# 79  1995000.0                483 S Ogden Street Denver CO 80209                3           4    3744      Multi-family  https://www.zillow.com/homedetails/483-S-Ogden...         NaN
# 26  1899000.0                1281 S High Street Denver CO 80210                5           3    3514             House  https://www.zillow.com/homedetails/1281-S-High...         NaN
# 66  1750000.0             1225 S Downing Street Denver CO 80210                5           3    3078             House  https://www.zillow.com/homedetails/1225-S-Down...         NaN
# 24  1700000.0            770 N Lafayette Street Denver CO 80218                3           4    3236             House  https://www.zillow.com/homedetails/1089-S-Ogde...         NaN
# 85  1695000.0                3414 W 31st Avenue Denver CO 80211                3           4    3326             House  https://www.zillow.com/homedetails/3414-W-31st...         NaN
# 30  1559000.0                   2875 S Williams Denver CO 80210                5           4    3321             House  https://www.zillow.com/homedetails/2875-S-Will...         NaN
# 74  1450000.0              2538 Clarkson Street Denver CO 80205                4           4    3215             House  https://www.zillow.com/homedetails/2538-N-Clar...         NaN
# 18  1395000.0                3409 Navajo Street Denver CO 80211                3           3    2412       Coming_soon  https://www.zillow.com/homedetails/3409-N-Nava...         NaN
# 73  1300000.0                43 Garfield Street Denver CO 80206                5           4    3759      Multi-family  https://www.zillow.com/homedetails/43-Garfield...         NaN
# 82  1290000.0               111 Harrison Street Denver CO 80206                2           3    2785             House  https://www.zillow.com/homedetails/111-Harriso...         NaN
# 19  1225000.0                1432 S Vine Street Denver CO 80210                4           2    1912       Coming_soon  https://www.zillow.com/homedetails/1432-S-Vine...         NaN
# 61  1165000.0                7787 E 24th Avenue Denver CO 80238                5           4    4428             House  https://www.zillow.com/homedetails/7787-E-24th...         NaN
# 38  1149000.0             1420 Columbine Street Denver CO 80206                4           3    3339             House  https://www.zillow.com/homedetails/1420-Columb...         NaN
# 39  1050000.0                      4290 King St Denver CO 80211                3           3    2346             House  https://www.zillow.com/homedetails/4290-King-S...         NaN
# 1   1000000.0                 2624 Wolff Street Denver CO 80212                3           3    1791             House  https://www.zillow.com/homedetails/2624-Wolff-...  354.609929
# 6   1000000.0                 658 Steele Street Denver CO 80206                3           2    2467             House  https://www.zillow.com/homedetails/658-Steele-...  682.087782
# 52   989000.0        2937 Champa Street  Unit A Denver CO 80205                3           4    2577             Condo  https://www.zillow.com/homedetails/2937-Champa...         NaN
# 15   985000.0                    2560 Champa St Denver CO 80205                4           3    2297             House  https://www.zillow.com/homedetails/2560-Champa...         NaN
# 43   950000.0               2044 Gaylord Street Denver CO 80205                3           2    3219             House  https://www.zillow.com/homedetails/2044-N-Gayl...         NaN
# 25   915000.0               1089 S Ogden Street Denver CO 80209                3           2    2080       Coming_soon  https://www.zillow.com/homedetails/2836-N-York...         NaN
# 29   860000.0              1345 S Corona Street Denver CO 80210                3           2    1342             House  https://www.zillow.com/homedetails/1345-S-Coro...         NaN
# 70   850000.0                 3334 Olive Street Denver CO 80207                5           2    2152             House  https://www.zillow.com/homedetails/3334-Olive-...         NaN
# 78   850000.0               5841 N Boston Court Denver CO 80238                4           4    2640             House  https://www.zillow.com/homedetails/5841-N-Bost...         NaN
# 2    825000.0                  464 S Ivy Street Denver CO 80224                3           2    1522             House  https://www.zillow.com/homedetails/464-S-Ivy-S...  463.195691
# 84   825000.0              532 S Lincoln Street Denver CO 80209                4           2    1949      Multi-family  https://www.zillow.com/homedetails/532-S-Linco...         NaN
# 33   825000.0     1801 Wynkoop Street  Unit 208 Denver CO 80202                2           2    1260       Coming_soon  https://www.zillow.com/homedetails/1801-Wynkoo...         NaN
# 49   800000.0              8071 E Bayaud Avenue Denver CO 80230                4           4    2515             House  https://www.zillow.com/homedetails/8071-E-Baya...         NaN
# 76   775000.0             1427 N Emerson Street Denver CO 80218                3           3    1802         Townhouse  https://www.zillow.com/homedetails/1427-N-Emer...         NaN
# 31   775000.0             1219 S Sherman Street Denver CO 80210                2           1    1027             House  https://www.zillow.com/homedetails/1219-S-Sher...         NaN
# 71   770000.0   6900 W Grant Ranch Boulevard  Unit 9 Denver C...               2           3    3548             House  https://www.zillow.com/homedetails/6900-W-Gran...         NaN
# 55   750000.0                  865 Grape Street Denver CO 80220                3           2    1864             House  https://www.zillow.com/homedetails/865-Grape-S...         NaN
# 20   750000.0                4445 Xavier Street Denver CO 80212                3           2    1581       Coming_soon  https://www.zillow.com/homedetails/4445-Xavier...         NaN
# 36   750000.0                4545 Batavia Place Denver CO 80220                4           2    2120             House  https://www.zillow.com/homedetails/4545-Batavi...         NaN
# 10   742000.0               1835 S Adams Street Denver CO 80210                3           2    1670             House  https://www.zillow.com/homedetails/1835-S-Adam...         NaN
# 60   700000.0              3227 N Steele Street Denver CO 80205                3           2    1728      Multi-family  https://www.zillow.com/homedetails/3227-N-Stee...         NaN
# 47   699000.0                3203 N Vine Street Denver CO 80205                3           1    1649             House  https://www.zillow.com/homedetails/3203-N-Vine...         NaN
# 34   695000.0                5138 W 46th Avenue Denver CO 80212                3           2    1680             House  https://www.zillow.com/homedetails/5138-W-46th...         NaN
# 68   695000.0                 1265 Perry Street Denver CO 80204                3           4    1596             House  https://www.zillow.com/homedetails/1265-Perry-...         NaN
# 35   675000.0                3527 W 45th Avenue Denver CO 80211                2           2    1019       Coming_soon  https://www.zillow.com/homedetails/3527-W-45th...         NaN
# 62   650000.0                4070 W 13th Avenue Denver CO 80204                2           3    1350         Townhouse  https://www.zillow.com/homedetails/4070-W-13th...         NaN
# 83   649000.0     345 Fillmore Street  Unit 102 Denver CO 80206                2           2    1069             Condo  https://www.zillow.com/homedetails/345-N-Fillm...         NaN
# 56   620000.0                19531 E 40th Place Denver CO 80249                6           4    3533             House  https://www.zillow.com/homedetails/19531-E-40t...         NaN
# 46   619000.0                    848 Knox Court Denver CO 80204                3           2    1381             House  https://www.zillow.com/homedetails/848-Knox-Ct...         NaN
# 17   600000.0         3047 Tejon Street  Unit A Denver CO 80211                2           2     960             Condo  https://www.zillow.com/homedetails/3047-N-Tejo...         NaN
# 59   599900.0                  4901 Green Court Denver CO 80221                3           2    1156             House  https://www.zillow.com/homedetails/4901-Green-...         NaN
# 50   599000.0                2954 Geneva Street Denver CO 80238                3           3    1531       Coming_soon  https://www.zillow.com/homedetails/2954-Geneva...         NaN
# 21   595000.0        930 Acoma Street  Unit 318 Denver CO 80204                2           2    1388             Condo  https://www.zillow.com/homedetails/930-Acoma-S...         NaN
# 14   590000.0             3730 N Madison Street Denver CO 80205                3           2    1277       Coming_soon  https://www.zillow.com/homedetails/3730-N-Madi...         NaN
# 48   579000.0           4765 N Kittredge Street Denver CO 80239                3           3    2347             House  https://www.zillow.com/homedetails/4765-Kittre...         NaN
# 86   575000.0                3431 E 29th Avenue Denver CO 80205                2           1     843             House  https://www.zillow.com/homedetails/3431-E-29th...         NaN
# 23   570000.0                4107 Dunkirk Court Denver CO 80249                3           3    2107             House  https://www.zillow.com/homedetails/770-N-Lafay...         NaN
# 72   560000.0                3835 Julian Street Denver CO 80211                2           1     930      Multi-family  https://www.zillow.com/homedetails/3835-Julian...         NaN
# 41   550000.0             273 S Franklin Street Denver CO 80209                1           1     959      Multi-family  https://www.zillow.com/homedetails/273-S-Frank...         NaN
# 9    499999.0                5559 Lisbon Street Denver CO 80249                4           3    1731             House  https://www.zillow.com/homedetails/5559-Lisbon...         NaN
# 44   475000.0            1232 S Mariposa Street Denver CO 80223                3           2    1088             House  https://www.zillow.com/homedetails/1232-S-Mari...         NaN
# 13   475000.0                 20029 Elgin Drive Denver CO 80249                2           3    1460             House  https://www.zillow.com/homedetails/20029-Elgin...         NaN
# 69   470000.0   400 S Lafayette Street  Unit 1103 Denver CO 8...               2           2     943             Condo  https://www.zillow.com/homedetails/400-S-Lafay...         NaN
# 40   460000.0              232 S Zenobia Street Denver CO 80219                2           1    1044       Coming_soon  https://www.zillow.com/homedetails/232-S-Zenob...         NaN
# 51   448500.0              16186 E Warner Drive Denver CO 80239                3           3    1643         Townhouse  https://www.zillow.com/homedetails/16186-E-War...         NaN
# 28   445000.0                1126 Quince Street Denver CO 80220                2           1     713             House  https://www.zillow.com/homedetails/1126-Quince...         NaN
# 65   417500.0                   744 Hazel Court Denver CO 80204                2           1    1386         Townhouse  https://www.zillow.com/homedetails/744-Hazel-C...         NaN
# 5    390000.0     2193 Arapahoe Street  Unit 16 Denver CO 80205                1           1     687             Condo  https://www.zillow.com/homedetails/2193-Arapah...  509.621167
# 57   374000.0     1975 N Grant Street  Unit 609 Denver CO 80203                1           2     672             Condo  https://www.zillow.com/homedetails/1975-N-Gran...         NaN
# 27   368500.0              2930 W Mexico Avenue Denver CO 80219                2           1     618             House  https://www.zillow.com/homedetails/2930-W-Mexi...         NaN
# 32   352000.0              13361 Randolph Place Denver CO 80239                3           3    1974             House  https://www.zillow.com/homedetails/13361-Rando...         NaN
# 4    350000.0        2910 Bruce Randolph Avenue Denver CO 80205                3           3    1956         Townhouse  https://www.zillow.com/homedetails/2910-Bruce-...  423.293997
# 8    350000.0        950 N Ogden Street  Unit 6 Denver CO 80218                2           2    1458             Condo  https://www.zillow.com/homedetails/950-N-Ogden...  601.169844
# 3    350000.0       1356 Pearl Street  Unit 309 Denver CO 80203                2           2     808             Condo  https://www.zillow.com/homedetails/1356-N-Pear...  607.109448
# 53   325000.0   2220 E Mississippi Avenue  Unit 7 Denver CO 8...               1           1     610             Condo  https://www.zillow.com/homedetails/2220-E-Miss...         NaN
# 64   319000.0   7995 E Mississippi Avenue  Unit H9 Denver CO ...               2           2    1142         Townhouse  https://www.zillow.com/homedetails/7995-E-Miss...         NaN
# 45   315000.0    1301 Speer Boulevard  Unit 301 Denver CO 80204                1           1     637             Condo  https://www.zillow.com/homedetails/1301-N-Spee...         NaN
# 42   315000.0          775 S Alton Way  Unit 7d Denver CO 80247                2           2    1200             Condo  https://www.zillow.com/homedetails/775-S-Alton...         NaN
# 37   304900.0         444 17th Street  Unit 904 Denver CO 80202                1           1     632             Condo  https://www.zillow.com/homedetails/444-17th-St...         NaN
# 81   300000.0                 4531 Pearl Street Denver CO 80216                1           1     846             House  https://www.zillow.com/homedetails/4531-Pearl-...         NaN
# 7    299000.0               1520 W Alaska Place Denver CO 80223                2           1     701             House  https://www.zillow.com/homedetails/1520-W-Alas...  798.776343
# 63   280000.0    1045 Clarkson Street  Unit 105 Denver CO 80218                1           1     560             Condo  https://www.zillow.com/homedetails/1045-N-Clar...         NaN
# 0    279500.0   4899 S Dudley Street  Unit G4 Littleton CO 80...               2           1     706             Condo  https://www.zillow.com/homedetails/4899-S-Dudl...  821.917808
# 16   275000.0     9444 E Girard Avenue  Unit 12 Denver CO 80231                2           2    1004             Condo  https://www.zillow.com/homedetails/9444-E-Gira...         NaN
# 75   267000.0   2225 Buchtel Boulevard  Unit 409 Denver CO 80...               2           1     885             Condo  https://www.zillow.com/homedetails/2225-Buchte...         NaN
# 67   240000.0                1561 Wabash Street Denver CO 80220                1           1     550         Townhouse  https://www.zillow.com/homedetails/1561-Wabash...         NaN
# 11   216000.0                 1125 Xenia Street Denver CO 80220                2           1     732      Multi-family  https://www.zillow.com/homedetails/1125-Xenia-...         NaN
# 58   215000.0          735 S Alton Way  Unit 3a Denver CO 80247                1           1     855      Multi-family  https://www.zillow.com/homedetails/735-S-Alton...         NaN
# 80   180000.0        215 E 11th Avenue  Unit A6 Denver CO 80203   Studio</li><li  class="">1     219             Condo  https://www.zillow.com/homedetails/215-E-11th-...         NaN
# 22        0.0      Available Soon Plan wee-Cottage at North End               --          --      --  New_construction  https://www.zillow.com/homedetails/4107-Dunkir...         NaN

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 12 to 22
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prices      89 non-null     float64
#  1   address     89 non-null     object
#  2   beds        89 non-null     object
#  3   baths       89 non-null     object
#  4   sq_feet     89 non-null     object
#  5   type        89 non-null     object
#  6   links       89 non-null     object
#  7   sqft_price  9 non-null      float64
# dtypes: float64(2), object(6)
# memory usage: 6.3+ KB

# %%
# for i in soup3:
#         address = soup3.find_all (class_= 'list-card-addr')
#         price = list(soup3.find_all (class_='list-card-price'))
#         beds = list(soup3.find_all("ul", class_="list-card-details"))
#         details = soup3.find_all ('div', {'class': 'list-card-details'})
#         home_type = soup3.find_all ('div', {'class': 'list-card-footer'})
#         last_updated = soup3.find_all ('div', {'class': 'list-card-top'})
#         brokerage = list(soup3.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
#         link = soup3.find_all (class_= 'list-card-link')


# #create dataframe columns out of variables
# df['prices'] = price
# df['address'] = address
# df['beds'] = beds


# #create empty url list
# urls = []

# #loop through url, pull the href and strip out the address tag
# for link in soup3.find_all("article"):
#     href = link.find('a',class_="list-card-link")
#     if href == None:
#         addresses = None
#     else:
#         addresses = href.find('address',class_="list-card-addr").get_text()
#     urls.append(addresses)
#     urls = [x for x in urls if x is not None]


# #import urls into a links column
# df['link'] = urls
# df['link'] = df['link'].astype('str')


# #remove html tags
# df['link'] = df['link'].replace(',', '', regex=True)
# df['link'] = df['link'].replace(' ', '-', regex=True)
# df['link'] = 'https://www.zillow.com/homedetails/' + df['link'].astype(str)

# #convert columns to str
# df['prices'] = df['prices'].astype('str')
# df['address'] = df['address'].astype('str')
# df['beds'] = df['beds'].astype('str')

# #remove html tags
# df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
# df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
# df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
# df['address'] = df['address'].replace('</address>', ' ', regex=True)
# df['prices'] = df['prices'].str.replace(r'\D', '')

# #remove html tags from beds column
# df['beds'] = df['beds'].replace('<ul class="list-card-details"><li>', ' ', regex=True)
# df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li>', ' ', regex=True)
# df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->bds</abbr></li><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->ba</abbr></li><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->bd</abbr></li><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<abbr class="list-card-label"> ', ' ', regex=True)
# df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li></ul>', ' ', regex=True)
# df['beds'] = df['beds'].replace('Studio</li><liclass=""', '0', regex=True)
# df['beds'] = df['beds'].replace('Studio</li><li>', '0', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Townhouse for sale</li></ul>', 'Townhouse ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
# df['beds'] = df['beds'].replace(' <!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Condo for sale</li></ul>', 'Condo ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Coming soon</li></ul>', 'Coming_soon ', regex=True)

# #split beds column into beds, bath and sq_feet
# df[['beds','baths','sq_feet', 'type']] = df.beds.str.split(expand=True)

# #remove commas from sq_feet and convert to float
# df.replace(',','', regex=True, inplace=True)

# #drop nulls
# df = df[(df['prices'] != '') & (df['prices']!= ' ')]

# #convert column to float
# df['prices'] = df['prices'].astype('float')
# # d['sq_feet'] = df['sq_feet'].astype('float')

# #remove spaces from link column
# df['link'] = df.link.str.replace(' ','')

# #rearrange the columns
# df = df[['prices', 'address', 'link', 'beds', 'baths', 'sq_feet', 'type']]

# try_link = []
# for link in soup3.find_all('a'):
#     a = link.get('href')
#     try_link.append(a)


# df_2 = pd.DataFrame(try_link, columns = ['links'])
# df_2.dropna(inplace=True)
# df_2.drop_duplicates(inplace=True)
# try_link = df_2[df_2['links'].str.startswith('https://www.zillow.com/homedetails')]
# try_link.reset_index(inplace=True)


# df = df.merge(try_link, left_index=True, right_index=True)
# df = df.drop(['link','index'], axis =1)
# df

# %%
#df.to_csv('output.csv')

# %%
#df
