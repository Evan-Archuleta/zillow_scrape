# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext

#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

#add headers in case you use chromedriver (captchas are no fun); namely used for chromedriver
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
#create url variables for each zillow page
with requests.Session() as s:
    city = 'denver/' #*****change this city to what you want!!!!*****
    
    url = 'https://www.zillow.com/homes/for_sale/'+city
    url2 = 'https://www.zillow.com/homes/for_sale/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_sale/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_sale/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_sale/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_sale/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_sale/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_sale/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_sale/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_sale/'+city+'/10_p/'

    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

page_links = [soup, soup1, soup2, soup3, soup4, soup5, soup6, soup7, soup8, soup9]

#create the first two dataframes
df_master = pd.DataFrame()
df = pd.DataFrame()
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()

dataframe_list = [df,df1,df2,df3, df4,df5,df6,df7,df8,df9,df10]

# %%
for df, soup in zip(dataframe_list, page_links):
    #all for loops are pulling the specified variable using beautiful soup and inserting into said variable
    for i in soup:
        address = soup.find_all (class_= 'list-card-addr')
        price = list(soup.find_all (class_='list-card-price'))
        beds = list(soup.find_all("ul", class_="list-card-details"))
        details = soup.find_all ('div', {'class': 'list-card-details'})
        home_type = soup.find_all ('div', {'class': 'list-card-footer'})
        last_updated = soup.find_all ('div', {'class': 'list-card-top'})
        brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
        link = soup.find_all (class_= 'list-card-link')


        #create dataframe columns out of variables
        df['prices'] = price
        df['address'] = address
        df['beds'] = beds


    #create empty url list
    urls = []

    #loop through url, pull the href and strip out the address tag
    for link in soup.find_all("article"):
        href = link.find('a',class_="list-card-link")
        if href == None:
            addresses = None
        else:
            addresses = href.find('address',class_="list-card-addr").get_text()
        urls.append(addresses)
        urls = [x for x in urls if x is not None]


    #import urls into a links column
    df['link'] = urls
    df['link'] = df['link'].astype('str')


    #remove html tags
    df['link'] = df['link'].replace(',', '', regex=True)
    df['link'] = df['link'].replace(' ', '-', regex=True)
    df['link'] = 'https://www.zillow.com/homedetails/' + df['link'].astype(str)

    #convert columns to str
    df['prices'] = df['prices'].astype('str')
    df['address'] = df['address'].astype('str')
    df['beds'] = df['beds'].astype('str')

    #remove html tags
    df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
    df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
    df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
    df['address'] = df['address'].replace('</address>', ' ', regex=True)
    df['prices'] = df['prices'].str.replace(r'\D', '')

    #remove html tags from beds column
    df['beds'] = df['beds'].replace('<ul class="list-card-details"><li>', ' ', regex=True)
    df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li>', ' ', regex=True)
    df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->bds</abbr></li><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->ba</abbr></li><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->bd</abbr></li><li class="">', ' ', regex=True)
    df['beds'] = df['beds'].replace('<abbr class="list-card-label"> ', ' ', regex=True)
    df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li></ul>', ' ', regex=True)
    df['beds'] = df['beds'].replace('Studio</li><liclass=""', '0', regex=True)
    df['beds'] = df['beds'].replace('Studio</li><li>', '0', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Townhouse for sale</li></ul>', 'Townhouse ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
    df['beds'] = df['beds'].replace(' <!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Condo for sale</li></ul>', 'Condo ', regex=True)
    df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Coming soon</li></ul>', 'Coming_soon ', regex=True)
    df['beds'] = df['beds'].replace(' <!-- -->sqft</abbr></li><li class="list-card-statusText">- New construction</li></ul>', ' New_construction ', regex=True)
    
    #split beds column into beds, bath and sq_feet
    df[['beds','baths','sq_feet', 'type']] = df.beds.str.split(expand=True)

    #remove commas from sq_feet and convert to float
    df.replace(',','', regex=True, inplace=True)

    #drop nulls
    df = df[(df['prices'] != '') & (df['prices']!= ' ')]

    #convert column to float
    df['prices'] = df['prices'].astype('float')
    # d['sq_feet'] = df['sq_feet'].astype('float')

    #remove spaces from link column
    df['link'] = df.link.str.replace(' ','')

    #rearrange the columns
    df = df[['prices', 'address', 'link', 'beds', 'baths', 'sq_feet', 'type']]

    try_link = []
    for link in soup.find_all('a'):
        a = link.get('href')
        try_link.append(a)


    df_2 = pd.DataFrame(try_link, columns = ['links'])
    df_2.dropna(inplace=True)
    df_2.drop_duplicates(inplace=True)
    try_link = df_2[df_2['links'].str.startswith('https://www.zillow.com/homedetails')]
    try_link.reset_index(inplace=True)


    df = df.merge(try_link, left_index=True, right_index=True)
    df = df.drop(['link','index'], axis =1)
    df_master = df_master.append(df, ignore_index = True)
# Out:
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:54: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
# C:\Users\evan\AppData\Local\Temp\ipykernel_17740\3199858393.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_master = df_master.append(df, ignore_index = True)

# %%
df_master.drop_duplicates(inplace=True)
df_master.to_csv('output.csv', index=False)

# %%
df_master
# Out:
#         prices                                            address            beds       baths sq_feet          type                                              links
# 0     579000.0              1800 S Stuart Street Denver CO 80219                3           1    1116         House  https://www.zillow.com/homedetails/1800-S-Stua...
# 1     649000.0        891 14th Street  Unit 1917 Denver CO 80202                1           1    1001         Condo  https://www.zillow.com/homedetails/891-14th-St...
# 2     249000.0   3141 S Tamarac Drive  Unit G106 Denver CO 80231                1           1     714         Condo  https://www.zillow.com/homedetails/3141-S-Tama...
# 3     444900.0              16041 E Warner Place Denver CO 80239                3           3    1538     Townhouse  https://www.zillow.com/homedetails/16041-E-War...
# 4     775000.0        617 S University Boulevard Denver CO 80209                3           2    2084         House  https://www.zillow.com/homedetails/617-S-Unive...
# 5     545000.0         3090 Wilson Court  Unit 2 Denver CO 80205                2           3    1336     Townhouse  https://www.zillow.com/homedetails/3090-Wilson...
# 6    1250000.0             547 S Williams Street Denver CO 80209                1           1    1221         House  https://www.zillow.com/homedetails/547-S-Willi...
# 7     480000.0               18945 E 45th Avenue Denver CO 80249                3           3    2519         House  https://www.zillow.com/homedetails/18945-E-45t...
# 8    1000000.0                 658 Steele Street Denver CO 80206                3           2    2467         House  https://www.zillow.com/homedetails/658-Steele-...
# 9    1100000.0                936 N Ogden Street Denver CO 80148               --          --    2415  Multi-family  https://www.zillow.com/homedetails/936-N-Ogden...
# 10    450000.0            12274 E Berkeley Place Denver CO 80239                2           1     848         House  https://www.zillow.com/homedetails/12274-E-Ber...
# 11    850000.0              238 S Downing Street Denver CO 80209                3           2    2418         House  https://www.zillow.com/homedetails/238-S-Downi...
# 12    774900.0                  2836 York Street Denver CO 80205                3           2    2214         House  https://www.zillow.com/homedetails/2836-N-York...
# 13    500000.0               20811 E 45th Avenue Denver CO 80249                3           2    1456         House  https://www.zillow.com/homedetails/20811-E-45t...
# 14  10000000.0               121 S Dexter Street Denver CO 80246                7          10   10268         House  https://www.zillow.com/homedetails/121-S-Dexte...
# 15    350000.0       1356 Pearl Street  Unit 309 Denver CO 80203                2           2     808         Condo  https://www.zillow.com/homedetails/1356-N-Pear...
# 16    499999.0                5559 Lisbon Street Denver CO 80249                4           3    1731         House  https://www.zillow.com/homedetails/5559-Lisbon...
# 17    700000.0              3227 N Steele Street Denver CO 80205                3           2    1728  Multi-family  https://www.zillow.com/homedetails/3227-N-Stee...
# 18    615000.0      2460 W 29th Avenue  Unit 302 Denver CO 80211                2           2    1175         Condo  https://www.zillow.com/homedetails/2460-W-29th...
# 19    565000.0              5044 Billings Street Denver CO 80239                5           3    2285         House  https://www.zillow.com/homedetails/5044-Billin...
# 20    989000.0        2937 Champa Street  Unit A Denver CO 80205                3           4    2577         Condo  https://www.zillow.com/homedetails/2937-Champa...
# 21    368500.0              2930 W Mexico Avenue Denver CO 80219                2           1     618         House  https://www.zillow.com/homedetails/2930-W-Mexi...
# 22    930000.0               6890 E Iliff Avenue Denver CO 80224                5           4    3630   Coming_soon  https://www.zillow.com/homedetails/6890-E-Ilif...
# 23   1100000.0                   2291 Elm Street Denver CO 80207                4           3    2400   Coming_soon  https://www.zillow.com/homedetails/2291-Elm-St...
# 24    545000.0           5565 N Kittredge Street Denver CO 80239                3           3    2081         House  https://www.zillow.com/homedetails/5565-Kittre...
# 25    385000.0         5800 Tower Road  Unit 203 Denver CO 80249                2           2    1109         Condo  https://www.zillow.com/homedetails/5800-N-Towe...
# 26    895000.0              19 S Harrison Street Denver CO 80209                3           4    2188     Townhouse  https://www.zillow.com/homedetails/19-S-Harris...
# 27    750000.0                4545 Batavia Place Denver CO 80220                4           2    2120         House  https://www.zillow.com/homedetails/4545-Batavi...
# 28    750000.0                 9351 E 5th Avenue Denver CO 80230                3           3    2842         House  https://www.zillow.com/homedetails/9351-E-5th-...
# 29   5950000.0               375 N Gilpin Street Denver CO 80218                6           5    6689         House  https://www.zillow.com/homedetails/375-N-Gilpi...
# 30    599900.0                  4901 Green Court Denver CO 80221                3           2    1156         House  https://www.zillow.com/homedetails/4901-Green-...
# 31    529900.0            1316 29th Ave UNIT 202 Denver CO 80205                2           1     977     Townhouse  https://www.zillow.com/homedetails/1316-29th-S...
# 32   1175000.0           1245 S Milwaukee Street Denver CO 80210                3           2    1847   Coming_soon  https://www.zillow.com/homedetails/1245-S-Milw...
# 33    660000.0              1992 S Cherry Street Denver CO 80222                3           3    2094     Townhouse  https://www.zillow.com/homedetails/1992-S-Cher...
# 34    724999.0     1700 Bassett Street  Unit 915 Denver CO 80202                2           1    1183         Condo  https://www.zillow.com/homedetails/1700-Basset...
# 35    600000.0          9863 W Saratoga Place Littleton CO 80123                4           3    2052         House  https://www.zillow.com/homedetails/9863-W-Sara...
# 36   1325000.0                810 Jasmine Street Denver CO 80220                5           4    4096         House  https://www.zillow.com/homedetails/810-Jasmine...
# 37   1250000.0                1625 Hudson Street Denver CO 80220                3           3    3338   Coming_soon  https://www.zillow.com/homedetails/1625-Hudson...
# 38   1690000.0               1968 Jasmine Street Denver CO 80220                4           3    2934         House  https://www.zillow.com/homedetails/1968-Jasmin...
# 39   1425000.0                         500 Birch Denver CO 80220                5           3    3639         House  https://www.zillow.com/homedetails/500-Birch-S...
# 40    954000.0                1330 Eudora Street Denver CO 80220                4           3    2508         House  https://www.zillow.com/homedetails/1330-Eudora...
# 41    775000.0               742 N Corona Street Denver CO 80218                4           3    2546     Townhouse  https://www.zillow.com/homedetails/742-N-Coron...
# 42    649999.0        1826 Irving Street  Unit 4 Denver CO 80204                2           3    1331     Townhouse  https://www.zillow.com/homedetails/1826-Irving...
# 43   3479000.0                 891 S York Street Denver CO 80209                5           5    5100         House  https://www.zillow.com/homedetails/891-S-York-...
# 44    700000.0            251 S Lafayette Street Denver CO 80209                2           2    1115         House  https://www.zillow.com/homedetails/251-S-Lafay...
# 45   4450000.0           2461 S Columbine Street Denver CO 80210                5           7    8383         House  https://www.zillow.com/homedetails/2461-S-Colu...
# 46   1150000.0               6841 Eastmoor Drive Denver CO 80237                5           4    3299   Coming_soon  https://www.zillow.com/homedetails/6841-Eastmo...
# 47    419900.0           7250 Eastmoor  Unit 112 Denver CO 80237                2           3    1593     Townhouse  https://www.zillow.com/homedetails/7250-Eastmo...
# 48    625000.0           7301 Montview Boulevard Denver CO 80220                4           3    2228         House  https://www.zillow.com/homedetails/7301-E-Mont...
# 49    315000.0        1356 Pearl Street  Unit B2 Denver CO 80203                2           1     747         Condo  https://www.zillow.com/homedetails/1356-N-Pear...
# 50    890000.0                 1929 Grove Street Denver CO 80204                3           3    1848     Townhouse  https://www.zillow.com/homedetails/1929-Grove-...
# 51    579000.0           4765 N Kittredge Street Denver CO 80239                3           3    2347         House  https://www.zillow.com/homedetails/4765-Kittre...
# 52   1150000.0              331 S Sherman Street Denver CO 80209                4           4    2613         House  https://www.zillow.com/homedetails/331-S-Sherm...
# 53    149900.0         603 Inca Street  Unit 218 Denver CO 80204   Studio</li><li  class="">1     331         Condo  https://www.zillow.com/homedetails/603-Inca-St...
# 54    620000.0                19531 E 40th Place Denver CO 80249                6           4    3533         House  https://www.zillow.com/homedetails/19531-E-40t...
# 55   1200000.0             830 S Clarkson Street Denver CO 80209                3           3    2648   Coming_soon  https://www.zillow.com/homedetails/830-S-Clark...
# 56    949900.0               4172 S Olive Street Denver CO 80237                4           3    3263   Coming_soon  https://www.zillow.com/homedetails/4172-S-Oliv...
# 57    470000.0   400 S Lafayette Street  Unit 1103 Denver CO 8...               2           2     943         Condo  https://www.zillow.com/homedetails/400-S-Lafay...
# 58    419900.0   8725 W Berry Avenue  Unit 102 Littleton CO 80...               3           2    1219         Condo  https://www.zillow.com/homedetails/8725-W-Berr...
# 59   1650000.0             2243 S Jackson Street Denver CO 80210                4           3    4391         House  https://www.zillow.com/homedetails/2243-S-Jack...
# 60    885000.0        2028 W 33rd Avenue  Unit 2 Denver CO 80211                3           4    1753     Townhouse  https://www.zillow.com/homedetails/2028-W-33rd...
# 61    800000.0              1975 S Poplar Street Denver CO 80224                4           3    2496         House  https://www.zillow.com/homedetails/1975-S-Popl...
# 62    690000.0            2156 Federal Boulevard Denver CO 80211                3           2    1652         House  https://www.zillow.com/homedetails/2156-Federa...
# 63    997000.0           1466 S Milwaukee Street Denver CO 80210                5           2    2821         House  https://www.zillow.com/homedetails/1466-S-Milw...
# 64    600000.0           5253 W Amherst Avenue Lakewood CO 80227                3           3    2680         House  https://www.zillow.com/homedetails/5253-W-Amhe...
# 65    700000.0                3051 Fulton Street Denver CO 80238                3           4    2595     Townhouse  https://www.zillow.com/homedetails/3051-Fulton...
# 66    980000.0                 2822 Xenia Street Denver CO 80238                3           4    2645         House  https://www.zillow.com/homedetails/2822-N-Xeni...
# 67   1175000.0               327 Cherokee Street Denver CO 80223                2           2    2067   Coming_soon  https://www.zillow.com/homedetails/327-Cheroke...
# 68    609000.0               2910 Niagara Street Denver CO 80207                2           2    1485         House  https://www.zillow.com/homedetails/2910-Niagar...
# 69   1290000.0               1001 N Ogden Street Denver CO 80218                4           4    2988         House  https://www.zillow.com/homedetails/1001-N-Ogde...
# 70   1095000.0                9652 E 27th Avenue Denver CO 80238                5           4    3965         House  https://www.zillow.com/homedetails/9652-E-27th...
# 71    699000.0               5700 E Floyd Avenue Denver CO 80222                3           2    2085         House  https://www.zillow.com/homedetails/5700-E-Floy...
# 72   1825000.0   2000 Little Raven Street  Unit 3b Denver CO 8...               2           3    2452   Coming_soon  https://www.zillow.com/homedetails/2000-Little...
# 73    429999.0                272 S Meade Street Denver CO 80219                2           1     650         House  https://www.zillow.com/homedetails/272-S-Meade...
# 74    650000.0                4070 W 13th Avenue Denver CO 80204                2           3    1350     Townhouse  https://www.zillow.com/homedetails/4070-W-13th...
# 75    760000.0                  620 Pearl Street Denver CO 80203                3           2    1902         House  https://www.zillow.com/homedetails/620-N-Pearl...
# 76    304900.0         444 17th Street  Unit 904 Denver CO 80202                1           1     632         Condo  https://www.zillow.com/homedetails/444-17th-St...
# 77    695000.0                 1265 Perry Street Denver CO 80204                3           4    1596         House  https://www.zillow.com/homedetails/1265-Perry-...
# 78   3000000.0                   2485 Oak Street Denver CO 80212                5           5    5875         House  https://www.zillow.com/homedetails/2485-Oak-St...
# 79    447500.0              16040 E Warner Place Denver CO 80239                3           3    1538     Townhouse  https://www.zillow.com/homedetails/16040-E-War...
# 80    749900.0         6047 W Prentice Avenue Littleton CO 80123                4           3    2421         House  https://www.zillow.com/homedetails/6047-W-Pren...
# 81    399000.0              1170 Krameria Street Denver CO 80220                2           2    1874     Townhouse  https://www.zillow.com/homedetails/1170-Kramer...
# 82    570000.0        1530 S Quebec Way  Unit 28 Denver CO 80231                3           3    2229     Townhouse  https://www.zillow.com/homedetails/1530-S-Queb...
# 83   2695000.0              753 Milwaukee Street Denver CO 80206                5           5    4439         House  https://www.zillow.com/homedetails/753-Milwauk...
# 84    789000.0               2095 Monaco Parkway Denver CO 80207                3           3    2890         House  https://www.zillow.com/homedetails/2095-Monaco...
# 85    240000.0                1561 Wabash Street Denver CO 80220                1           1     550     Townhouse  https://www.zillow.com/homedetails/1561-Wabash...
# 86    425000.0        1020 15th Street  Unit 20c Denver CO 80202                2           2     989         Condo  https://www.zillow.com/homedetails/1020-15th-S...
# 87    375000.0   1060 Washington Street  Unit 302 Denver CO 80...               1           1     794         Condo  https://www.zillow.com/homedetails/1060-N-Wash...
# 88    775000.0                9101 E 61st Avenue Denver CO 80238                4           3    2502   Coming_soon  https://www.zillow.com/homedetails/9101-E-61st...
# 89    449900.0   909 N Lafayette Street  Unit 203 Denver CO 80...               2           2     983         Condo  https://www.zillow.com/homedetails/909-N-Lafay...

# %%
# for i in soup3:
#         address = soup3.find_all (class_= 'list-card-addr')
#         price = list(soup3.find_all (class_='list-card-price'))
#         beds = list(soup3.find_all("ul", class_="list-card-details"))
#         details = soup3.find_all ('div', {'class': 'list-card-details'})
#         home_type = soup3.find_all ('div', {'class': 'list-card-footer'})
#         last_updated = soup3.find_all ('div', {'class': 'list-card-top'})
#         brokerage = list(soup3.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
#         link = soup3.find_all (class_= 'list-card-link')


# #create dataframe columns out of variables
# df['prices'] = price
# df['address'] = address
# df['beds'] = beds


# #create empty url list
# urls = []

# #loop through url, pull the href and strip out the address tag
# for link in soup3.find_all("article"):
#     href = link.find('a',class_="list-card-link")
#     if href == None:
#         addresses = None
#     else:
#         addresses = href.find('address',class_="list-card-addr").get_text()
#     urls.append(addresses)
#     urls = [x for x in urls if x is not None]


# #import urls into a links column
# df['link'] = urls
# df['link'] = df['link'].astype('str')


# #remove html tags
# df['link'] = df['link'].replace(',', '', regex=True)
# df['link'] = df['link'].replace(' ', '-', regex=True)
# df['link'] = 'https://www.zillow.com/homedetails/' + df['link'].astype(str)

# #convert columns to str
# df['prices'] = df['prices'].astype('str')
# df['address'] = df['address'].astype('str')
# df['beds'] = df['beds'].astype('str')

# #remove html tags
# df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
# df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
# df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
# df['address'] = df['address'].replace('</address>', ' ', regex=True)
# df['prices'] = df['prices'].str.replace(r'\D', '')

# #remove html tags from beds column
# df['beds'] = df['beds'].replace('<ul class="list-card-details"><li>', ' ', regex=True)
# df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li>', ' ', regex=True)
# df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->bds</abbr></li><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->ba</abbr></li><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->bd</abbr></li><li class="">', ' ', regex=True)
# df['beds'] = df['beds'].replace('<abbr class="list-card-label"> ', ' ', regex=True)
# df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li></ul>', ' ', regex=True)
# df['beds'] = df['beds'].replace('Studio</li><liclass=""', '0', regex=True)
# df['beds'] = df['beds'].replace('Studio</li><li>', '0', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Townhouse for sale</li></ul>', 'Townhouse ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Multi-family home for sale</li></ul>', 'Multi-family ', regex=True)
# df['beds'] = df['beds'].replace(' <!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', 'House ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Condo for sale</li></ul>', 'Condo ', regex=True)
# df['beds'] = df['beds'].replace('<!-- -->sqft</abbr></li><li class="list-card-statusText">- Coming soon</li></ul>', 'Coming_soon ', regex=True)

# #split beds column into beds, bath and sq_feet
# df[['beds','baths','sq_feet', 'type']] = df.beds.str.split(expand=True)

# #remove commas from sq_feet and convert to float
# df.replace(',','', regex=True, inplace=True)

# #drop nulls
# df = df[(df['prices'] != '') & (df['prices']!= ' ')]

# #convert column to float
# df['prices'] = df['prices'].astype('float')
# # d['sq_feet'] = df['sq_feet'].astype('float')

# #remove spaces from link column
# df['link'] = df.link.str.replace(' ','')

# #rearrange the columns
# df = df[['prices', 'address', 'link', 'beds', 'baths', 'sq_feet', 'type']]

# try_link = []
# for link in soup3.find_all('a'):
#     a = link.get('href')
#     try_link.append(a)


# df_2 = pd.DataFrame(try_link, columns = ['links'])
# df_2.dropna(inplace=True)
# df_2.drop_duplicates(inplace=True)
# try_link = df_2[df_2['links'].str.startswith('https://www.zillow.com/homedetails')]
# try_link.reset_index(inplace=True)


# df = df.merge(try_link, left_index=True, right_index=True)
# df = df.drop(['link','index'], axis =1)
# df

# %%
#df.to_csv('output.csv')

# %%
#df
